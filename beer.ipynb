# %%
#Import libraries we need
import pandas as pd
import numpy as np
from pyomo.environ import *
from pyomo.opt import SolverFactory

# %%
#Loading the beer relative datasets, and concat those datasets 
beer = pd.read_csv("beer_profile_and_ratings.csv")
price = pd.read_csv("makeup_beer_price.csv",encoding= 'unicode_escape')
price = price['made up price']
beer = pd.concat([beer,price], axis = 1)

# %%
#Constraints: All number of reviews need to large than 25% of dataset’s.
num_reviews_25 = np.quantile(beer['number_of_reviews'], 0.25)
beer = beer[beer['number_of_reviews']>num_reviews_25]

# %%
#Cleaning up our dataset
beer = beer.dropna()
beer_data = beer.drop(['Name', 'Style', 'Brewery', 'Beer Name (Full)', 'Description', 'Min IBU', 'Max IBU', 'review_appearance', 'review_palate', 'made up price'], axis =1)
beer_data_contain = beer_data.drop(['review_aroma', 'review_taste', 'review_overall', 'number_of_reviews'], axis = 1)

# %%
#Transfer our data type from dataframe to list
beer_data_contain = beer_data_contain.values.tolist()
name = beer['Name'].tolist()
style = beer['Style'].tolist()
abv = beer['ABV'].tolist()
astringency = beer['Astringency'].tolist()
body = beer['Body'].tolist()
alcohol = beer['Alcohol'].tolist()
bitter = beer['Bitter'].tolist()
sweet = beer['Sweet'].tolist()
sour = beer['Sour'].tolist()
salty = beer['Salty'].tolist()
fruits = beer['Fruits'].tolist()
hoppy = beer['Hoppy'].tolist()
spices = beer['Spices'].tolist()
malty = beer['Malty'].tolist()
aroma = beer['review_aroma'].tolist()
taste = beer['review_taste'].tolist()
overall = beer['review_overall'].tolist()
price = price.tolist()

# %%
#Style constraint: each style (111 styles) of beer need at least one.
#As a result, we need to first find out the location of each group. 
temp_style = ' '
cutoff =[]
for s in range(len(style)):
    if style[s] != temp_style :
        cutoff.append(s)
    temp_style = style[s]
cutoff.append(len(style))

# %%
#Setting up the constraint relative variables and data 
num_style = len(beer.groupby('Style').count())
abv_25 = np.quantile(abv, 0.25)
abv_75 = np.quantile(abv, 0.75)
astringency_25 = np.quantile(astringency, 0.25)
astringency_75 = np.quantile(astringency, 0.75)
body_25 = np.quantile(body, 0.25)
body_75 = np.quantile(body, 0.75)
alcohol_25 = np.quantile(alcohol, 0.25)
alcohol_75 = np.quantile(alcohol, 0.75)
bitter_25 = np.quantile(bitter, 0.25)
bitter_75 = np.quantile(bitter, 0.75)
sweet_25 = np.quantile(sweet, 0.25)
sweet_75 = np.quantile(sweet, 0.75)
sour_25 = np.quantile(sour, 0.25)
sour_75 = np.quantile(sour, 0.75)
salty_25 = np.quantile(salty, 0.25)
salty_75 = np.quantile(salty, 0.75)
fruits_25 = np.quantile(fruits, 0.25)
fruits_75 = np.quantile(fruits, 0.75)
hoppy_25 = np.quantile(hoppy, 0.25)
hoppy_75 = np.quantile(hoppy, 0.75)
spices_25 = np.quantile(spices, 0.25)
spices_75 = np.quantile(spices, 0.75)
malty_25 = np.quantile(malty, 0.25)
malty_75 = np.quantile(malty, 0.75)
aroma_mean = np.mean(aroma)
taste_mean = np.mean(taste)
data_25 = [abv_25, astringency_25, body_25, alcohol_25, bitter_25, sweet_25, sour_25, salty_25, fruits_25, hoppy_25, spices_25, malty_25]
data_75 = [abv_75, astringency_75, body_75, alcohol_75, bitter_75, sweet_75, sour_75, salty_75, fruits_75, hoppy_75, spices_75, malty_75]

# %%
#Modeling
model = ConcreteModel()

#Input variables
num_beer = len(beer) #i 
num_contain = len(data_25) #j
bottle_upperlimit = 50
bottle_lowerlimit = 5
bottle_minimum = 3000
budget = 500000

#Generate our decision variables
model.x = Var(range(num_beer), domain = NonNegativeIntegers)
model.y = Var(range(num_beer), domain = Binary)


#Average AVB, Astringency, Body, Alcohol, Bitter, Sweet, Sour, Salty, Fruits, Hoppy, Spices, Malty need to be between 25% and 75% of the dataset’s. 
model.contain = ConstraintList()
for j in range(num_contain):
    model.contain.add(expr = sum(model.x[i] * beer_data_contain[i][j] for i in range(num_beer)) >= data_25[j]*sum(model.x[k] for k in range(num_beer)))
    model.contain.add(expr = sum(model.x[i] * beer_data_contain[i][j] for i in range(num_beer)) <= data_75[j]*sum(model.x[k] for k in range(num_beer)))

#Each kind of beer can at most import 50 bottles    
model.bottle_upperlimit = ConstraintList()
for i in range(num_beer):
    model.bottle_upperlimit.add(expr = model.x[i] - (bottle_upperlimit * model.y[i]) <= 0)
    
#If we want to purchase, must purchase more than 5 bottles
model.bottle_lowerlimit = ConstraintList()
for i in range(num_beer):
    model.bottle_lowerlimit.add(expr = model.x[i] - (bottle_lowerlimit * model.y[i]) >= 0)

#Each style (111 styles) of beer need at least one.
model.style = ConstraintList()
for z in range(len(cutoff)-1):
    model.style.add(expr = sum(model.x[i] for i in range(cutoff[z],cutoff[z+1]))>=1)

#Average review aroma and review taste rate need to be larger than 50% of dataset’s.    
model.Constraint_aroma = Constraint(expr = sum(model.x[i] * aroma[i] for i in range(num_beer)) >= aroma_mean*sum(model.x[k] for k in range(num_beer)))
model.Constraint_taste = Constraint(expr = sum(model.x[i] * taste[i] for i in range(num_beer)) >= taste_mean*sum(model.x[k] for k in range(num_beer)))

#Budget constraint
model.Constraint_price = Constraint(expr = sum(model.x[i] * price[i] for i in range(num_beer)) <= budget)

#Average overall rate >= 4
total_overall = sum(model.x[i] * overall[i] for i in range(num_beer))
total_bottle = sum(model.x[k] for k in range(num_beer))
model.Constraint_average_overall = Constraint(expr = total_overall >= 4*total_bottle)

#Bottle Minimum constraint
model.constraint_bottle_minimum = Constraint(expr = sum(model.x[i] for i in range(num_beer)) >= bottle_minimum  )

#Objective : Minimize Cost
total_cost = sum(model.x[i] * price[i] for i in range(num_beer))
model.Objective = Objective(expr = total_cost, sense = minimize)

# %%
#Optimize and print the total cost and average overall rate
opt = SolverFactory('glpk')
opt.options['mipgap'] = 0.02
results = opt.solve(model, tee = True)
print("Obj: Total Cost:", model.Objective())
print("Average Overall Rate", total_overall()/total_bottle())
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --mipgap 0.02 --write /var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmp628xec54.glpk.raw
#  --wglp /var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmpswfb7bf5.glpk.glp
#  --cpxlp /var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmpl350xq0p.pyomo.lp
# Reading problem data from '/var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmpl350xq0p.pyomo.lp'...
# /var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmpl350xq0p.pyomo.lp:102181: warning: lower bound of variable 'x2385' redefined
# /var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmpl350xq0p.pyomo.lp:102181: warning: upper bound of variable 'x2385' redefined
# 4909 rows, 4769 columns, 77908 non-zeros
# 4768 integer variables, 2384 of which are binary
# 104565 lines were read
# Writing problem data to '/var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmpswfb7bf5.glpk.glp'...
# 97267 lines were written
# GLPK Integer Optimizer 5.0
# 4909 rows, 4769 columns, 77908 non-zeros
# 4768 integer variables, 2384 of which are binary
# Preprocessing...
# 4898 rows, 4765 columns, 76870 non-zeros
# 4765 integer variables, 2381 of which are binary
# Scaling...
#  A: min|aij| =  1.127e-04  max|aij| =  2.371e+02  ratio =  2.104e+06
# GM: min|aij| =  2.908e-02  max|aij| =  3.439e+01  ratio =  1.182e+03
# EQ: min|aij| =  8.457e-04  max|aij| =  1.000e+00  ratio =  1.182e+03
# 2N: min|aij| =  4.883e-04  max|aij| =  1.562e+00  ratio =  3.200e+03
# Constructing initial basis...
# Size of triangular part is 4898
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 4898 rows, 4765 columns, 76870 non-zeros
#       0: obj =   2.044127321e+03 inf =   5.111e+02 (115)
#     360: obj =   4.109583057e+05 inf =   3.846e-13 (0) 1
# *   824: obj =   2.348782093e+05 inf =   7.816e-14 (0) 3
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   824: mip =     not found yet >=              -inf        (1; 0)
# Solution found by heuristic: 239903.794115
# Solution found by heuristic: 239902.82412
# Solution found by heuristic: 239901.854126
# Solution found by heuristic: 239900.884132
# +  1493: mip =   2.399008841e+05 >=   2.349964444e+05   2.0% (317; 10)
# +  2162: mip =   2.399008841e+05 >=   2.350161675e+05   2.0% (629; 15)
# +  2840: mip =   2.399008841e+05 >=   2.350254742e+05   2.0% (943; 20)
# +  3508: mip =   2.399008841e+05 >=   2.350403079e+05   2.0% (1248; 25)
# +  4174: mip =   2.399008841e+05 >=   2.350444424e+05   2.0% (1555; 30)
# +  4830: mip =   2.399008841e+05 >=   2.350536296e+05   2.0% (1857; 35)
# +  5498: mip =   2.399008841e+05 >=   2.350630169e+05   2.0% (2162; 40)
# +  6156: mip =   2.399008841e+05 >=   2.350671514e+05   2.0% (2467; 45)
# +  6823: mip =   2.399008841e+05 >=   2.350753568e+05   2.0% (2770; 50)
# +  7496: mip =   2.399008841e+05 >=   2.350787351e+05   2.0% (3075; 55)
# +  8158: mip =   2.399008841e+05 >=   2.350846780e+05   2.0% (3380; 61)
# Time used: 60.0 secs.  Memory used: 19.5 Mb.
# +  8815: mip =   2.399008841e+05 >=   2.350888558e+05   2.0% (3680; 66)
# +  9478: mip =   2.399008841e+05 >=   2.350949753e+05   2.0% (3985; 71)
# + 10141: mip =   2.399008841e+05 >=   2.350998261e+05   2.0% (4280; 76)
# + 10799: mip =   2.399008841e+05 >=   2.351008790e+05   2.0% (4581; 81)
# + 11412: mip =   2.399008841e+05 >=   2.351034492e+05   2.0% (4864; 86)
# RELATIVE MIP GAP TOLERANCE REACHED; SEARCH TERMINATED
# Time used:   82.2 secs
# Memory used: 24.0 Mb (25201199 bytes)
# Writing MIP solution to '/var/folders/n9/t_j1751j2636q1vf1wsyppsw0000gn/T/tmp628xec54.glpk.raw'...
# 9687 lines were written
# Obj: Total Cost: 239900.88413180996
# Average Overall Rate 4.00000016

# %%
#Print out the optimial import strategy
result_name = []
result_style = []
result_amount = []
result_unit_price = []
result_total_price= []
result_overall = []
for i in range(num_beer):
    if model.x[i]() > 0:
        result_name.append(name[i])
        result_style.append(style[i])
        result_amount.append(model.x[i]())
        result_unit_price.append(price[i])
        result_total_price.append(price[i]*model.x[i]())
        result_overall.append(overall[i])
        print('Name:', name[i],'Style: ', style[i],'Purchase', model.x[i](), 'bottles')
# Out:
# Name: Double Bag Style:  Altbier Purchase 5.0 bottles
# Name: Gratitude Style:  Barleywine - American Purchase 5.0 bottles
# Name: Bourbon Barrel-Aged Barley Wine Style:  Barleywine - English Purchase 5.0 bottles
# Name: Bachelor ESB Style:  Bitter - English Extra Special / Strong Bitter (ESB) Purchase 50.0 bottles
# Name: The Naughty Nurse Style:  Bitter - English Purchase 5.0 bottles
# Name: Malheur Bière Brut (Brut Reserve) Style:  Bière de Champagne / Bière Brut Purchase 5.0 bottles
# Name: Citra Blonde Summer Brew Style:  Blonde Ale - American Purchase 50.0 bottles
# Name: De Koninck Blond Style:  Blonde Ale - Belgian Purchase 5.0 bottles
# Name: Spaten Optimator Style:  Bock - Doppelbock Purchase 50.0 bottles
# Name: Ramstein Winter Wheat Eisbock Style:  Bock - Eisbock Purchase 5.0 bottles
# Name: Narragansett Bock Style:  Bock - Maibock Purchase 5.0 bottles
# Name: St. Nikolaus Bock Bier Style:  Bock - Traditional Purchase 50.0 bottles
# Name: Moonglow Weizenbock Style:  Bock - Weizenbock Purchase 50.0 bottles
# Name: Slippery Slope Style:  Braggot Purchase 5.0 bottles
# Name: Defenestration Style:  Brett Beer Purchase 5.0 bottles
# Name: Old Brown Dog Style:  Brown Ale - American Purchase 5.0 bottles
# Name: Rejection Style:  Brown Ale - Belgian Dark Purchase 5.0 bottles
# Name: Nut Brown Ale Style:  Brown Ale - English Purchase 49.0 bottles
# Name: Skjálfti Style:  California Common / Steam Beer Purchase 5.0 bottles
# Name: Hot-Jala-Heim Style:  Chile Beer Purchase 5.0 bottles
# Name: Golden Ale Style:  Cream Ale Purchase 5.0 bottles
# Name: Trappist Westvleteren 8 (VIII)Brouwerij Westvleteren (Sint-Sixtusabdij van Westvleteren) Style:  Dubbel Purchase 50.0 bottles
# Name: Les Bière Des Sans Culottes Style:  Farmhouse Ale - Bière de Garde Purchase 5.0 bottles
# Name: Arctic Circle Ale Style:  Farmhouse Ale - Sahti Purchase 5.0 bottles
# Name: Rabbid Rabbit Style:  Farmhouse Ale - Saison Purchase 5.0 bottles
# Name: Autumn Maple Style:  Fruit and Field Beer Purchase 5.0 bottles
# Name: Ebulum Elderberry Black Ale Style:  Gruit / Ancient Herbed Ale Purchase 5.0 bottles
# Name: Kirin Tanrei Style:  Happoshu Purchase 5.0 bottles
# Name: Ta Henket Style:  Herb and Spice Beer Purchase 5.0 bottles
# Name: IPA Style:  IPA - American Purchase 50.0 bottles
# Name: Bedlam Style:  IPA - Belgian Purchase 6.0 bottles
# Name: NetherWorld Cascadian Dark Ale Style:  IPA - Black / Cascadian Dark Ale Purchase 5.0 bottles
# Name: Hitachino Nest Japanese Classic Ale Style:  IPA - English Purchase 5.0 bottles
# Name: Dorado Style:  IPA - Imperial Purchase 50.0 bottles
# Name: Double Sunshine Style:  IPA - Imperial Purchase 50.0 bottles
# Name: Heady Topper Style:  IPA - New England Purchase 50.0 bottles
# Name: Ochakovskiy Kvass Style:  Kvass Purchase 5.0 bottles
# Name: Sünner Kölsch Style:  Kölsch Purchase 50.0 bottles
# Name: Clearwater Kölsch Style:  Kölsch Purchase 50.0 bottles
# Name: Old Style Style:  Lager - Adjunct Purchase 5.0 bottles
# Name: Wisconsin Amber Style:  Lager - American Amber / Red Purchase 5.0 bottles
# Name: Sleeman Original Draught Style:  Lager - American Purchase 5.0 bottles
# Name: Shiner Fröst Style:  Lager - European / Dortmunder Export Purchase 5.0 bottles
# Name: DAB Dark Beer Style:  Lager - European Dark Purchase 5.0 bottles
# Name: Singha Style:  Lager - European Pale Purchase 5.0 bottles
# Name: Žaibo Style:  Lager - European Strong Purchase 5.0 bottles
# Name: Hacker-Pschorr Münchner Hell Style:  Lager - Helles Purchase 5.0 bottles
# Name: India Pale Lager Style:  Lager - India Pale Lager (IPL) Purchase 5.0 bottles
# Name: Koshihikari Echigo Beer Style:  Lager - Japanese Rice Purchase 5.0 bottles
# Name: Série Signature Kellerbier Style:  Lager - Kellerbier / Zwickelbier Purchase 5.0 bottles
# Name: Sankaty Light Style:  Lager - Light Purchase 5.0 bottles
# Name: Country Club Malt Liquor Style:  Lager - Malt Liquor Purchase 5.0 bottles
# Name: Saranac Long John Lager Style:  Lager - Munich Dunkel Purchase 5.0 bottles
# Name: Märzen Style:  Lager - Märzen / Oktoberfest Purchase 50.0 bottles
# Name: Rauchbier Style:  Lager - Rauchbier Purchase 5.0 bottles
# Name: Black Bavarian Style:  Lager - Schwarzbier Purchase 50.0 bottles
# Name: Jenny Lake Lager Style:  Lager - Vienna Purchase 50.0 bottles
# Name: Chapeau Faro Lambic Style:  Lambic - Faro Purchase 5.0 bottles
# Name: Fou' Foune Style:  Lambic - Fruit Purchase 5.0 bottles
# Name: Boon Oude Geuze Mariage Parfait Style:  Lambic - Gueuze Purchase 50.0 bottles
# Name: 50 Degrees North-4 Degrees East Style:  Lambic - Traditional Purchase 5.0 bottles
# Name: Clausthaler Golden Amber Style:  Low Alcohol Beer Purchase 5.0 bottles
# Name: Mild Winter Style:  Mild Ale - English Dark Purchase 5.0 bottles
# Name: Ossian Style:  Mild Ale - English Pale Purchase 5.0 bottles
# Name: Hibernation Ale - Barrel-Aged Style:  Old Ale Purchase 50.0 bottles
# Name: Alpha King Style:  Pale Ale - American Purchase 50.0 bottles
# Name: Redemption Style:  Pale Ale - Belgian Purchase 43.0 bottles
# Name: Brugse Zot Style:  Pale Ale - Belgian Purchase 47.0 bottles
# Name: Summer Ale Style:  Pale Ale - English Purchase 50.0 bottles
# Name: Unfiltered Double Barrel Ale Style:  Pale Ale - English Purchase 50.0 bottles
# Name: Mama's Little Yella Pils Style:  Pilsner - Bohemian / Czech Purchase 5.0 bottles
# Name: Dinkelacker CD-Pils Style:  Pilsner - German Purchase 5.0 bottles
# Name: The Curl Style:  Pilsner - Imperial Purchase 5.0 bottles
# Name: Porter Style:  Porter - American Purchase 50.0 bottles
# Name: Pipeline Porter Style:  Porter - American Purchase 50.0 bottles
# Name: Akevitt Style:  Porter - Baltic Purchase 50.0 bottles
# Name: Old-Style Porter Style:  Porter - English Purchase 50.0 bottles
# Name: Victory At Sea - Coffee And Vanilla Style:  Porter - Imperial Purchase 5.0 bottles
# Name: Porter Style:  Porter - Robust Purchase 5.0 bottles
# Name: Smoked Porter Style:  Porter - Smoked Purchase 5.0 bottles
# Name: Punkin Ale Style:  Pumpkin Beer Purchase 5.0 bottles
# Name: V-Twelve Style:  Quadrupel (Quad) Purchase 50.0 bottles
# Name: Judgment Day Style:  Quadrupel (Quad) Purchase 50.0 bottles
# Name: Censored Style:  Red Ale - American Amber / Red Purchase 50.0 bottles
# Name: Hop Head Red Ale Style:  Red Ale - Imperial Purchase 5.0 bottles
# Name: Saranac Irish Red Ale Style:  Red Ale - Irish Purchase 50.0 bottles
# Name: Casco Bay Riptide Red Ale Style:  Red Ale - Irish Purchase 50.0 bottles
# Name: Schleimhammer Roggenbier Style:  Rye Beer - Roggenbier Purchase 5.0 bottles
# Name: Red's Rye IPA Style:  Rye Beer Purchase 50.0 bottles
# Name: Ruthless Rye IPA Style:  Rye Beer Purchase 50.0 bottles
# Name: Traquair Jacobite Style:  Scotch Ale / Wee Heavy Purchase 50.0 bottles
# Name: Winter Ale Style:  Scottish Ale Purchase 50.0 bottles
# Name: Blackfriar Style:  Scottish Ale Purchase 50.0 bottles
# Name: Simple Malt Double Porter Style:  Smoked Beer Purchase 50.0 bottles
# Name: 1809 Style:  Sour - Berliner Weisse Purchase 5.0 bottles
# Name: Madame Rose Style:  Sour - Flanders Oud Bruin Purchase 50.0 bottles
# Name: Ned Style:  Sour - Flanders Red Ale Purchase 5.0 bottles
# Name: Imperial Cherry Gose Style:  Sour - Gose Purchase 5.0 bottles
# Name: Miles Davis' Bitches Brew Style:  Stout - American Imperial Purchase 5.0 bottles
# Name: Obsidian Stout Style:  Stout - American Purchase 50.0 bottles
# Name: London Stout Style:  Stout - English Purchase 5.0 bottles
# Name: Fade To Black - Volume 1 Style:  Stout - Foreign / Export Purchase 50.0 bottles
# Name: Old #38 Stout Style:  Stout - Irish Dry Purchase 5.0 bottles
# Name: Earl Coffee Oatmeal Stout Style:  Stout - Oatmeal Purchase 50.0 bottles
# Name: Beer Geek Bacon Style:  Stout - Oatmeal Purchase 50.0 bottles
# Name: Coffee Oatmeal Stout Style:  Stout - Oatmeal Purchase 50.0 bottles
# Name: Black OPS Style:  Stout - Russian Imperial Purchase 50.0 bottles
# Name: Sexual Chocolate Style:  Stout - Russian Imperial Purchase 50.0 bottles
# Name: Moo-Hoo Chocolate Milk Stout Style:  Stout - Sweet / Milk Purchase 5.0 bottles
# Name: Bell Ringer Style:  Strong Ale - American Purchase 5.0 bottles
# Name: Salvation Style:  Strong Ale - Belgian Dark Purchase 5.0 bottles
# Name: Boskeun Style:  Strong Ale - Belgian Pale Purchase 50.0 bottles
# Name: Geary's Hampshire Special Ale Style:  Strong Ale - English Purchase 5.0 bottles
# Name: Trappist Achel 8° Blond Style:  Tripel Purchase 50.0 bottles
# Name: Straffe Hendrik Bruges Tripel Bier 9° Style:  Tripel Purchase 50.0 bottles
# Name: River Guide Style:  Wheat Beer - American Dark Purchase 5.0 bottles
# Name: Gumballhead Style:  Wheat Beer - American Pale Purchase 5.0 bottles
# Name: Julius Echter Hefe-Weissbier Dunkel Style:  Wheat Beer - Dunkelweizen Purchase 5.0 bottles
# Name: Shotgun Betty Hefeweizen Ale Style:  Wheat Beer - Hefeweizen Purchase 5.0 bottles
# Name: Erdinger Weissbier Kristallklar Style:  Wheat Beer - Kristallweizen Purchase 50.0 bottles
# Name: Star Brew-Triple Wheat Ale Style:  Wheat Beer - Wheatwine Purchase 50.0 bottles
# Name: White Rascal Style:  Wheat Beer - Witbier Purchase 50.0 bottles
# Name: Consecration Style:  Wild Ale Purchase 5.0 bottles
# Name: Samuel Adams Old Fezziwig AleBoston Beer Company (Samuel Adams) Style:  Winter Warmer Purchase 5.0 bottles
# Name: God Jul Style:  Winter Warmer Purchase 50.0 bottles

# %%
#Store the result as a CSV file (Purchase_Beer_Strategy.csv)
d = {'Name':result_name,'Style':result_style, 'Unit Price':result_unit_price, 'Amount':result_amount, 'Total Price': result_total_price, 'Overall Rate': result_overall}
beer_import_data = pd.DataFrame(data= d)
beer_import_data.to_csv('Purchase_Beer_Strategy.csv', index=False)
